# %% [markdown]
# Description of observable trends based on the data
# 1. The cities around the Equator(0 dregree Latitude) have the highest temperatures as compared to the rest of the earth.
# 2. The teperatures and other weather parameter values vary significatly based on the time of the day that we are pulling the values from the Openweather Api as it might lead to different values.
# 3. The temperatures are the lowest at the poles as you move away from the equator towards the north and south poles.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key

from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %%
#Perform API Calls
#Perform a weather check on each city using a series of successive API calls.
#Include a print log of each city as it'sbeing processed (with the city number and city name).

# Set up the URL.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# setting up lists to hold reponse info
City = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_temp = []
Wind_Speed = []
counter = 0
Set = 1

# Looping through the list of cities and requesting for data on each
print("Beginning Data Retrieval ")
print("----------------------------")
for city in cities:
    response = requests.get(query_url + city).json()
    time.sleep(1)
    try:
        City.append(response['name'])
        Cloudiness.append(response['clouds']['all'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        Humidity.append(response['main']['humidity'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        Max_temp.append(response['main']['temp_max'])
        Wind_Speed.append(response['wind']['speed'])
        print(f"Processing Record {counter} of Set {Set} | {city}")
        if counter==49:
            counter=0
            Set+=1
        else:
            counter+=1
    except KeyError:
        print("City not found. Skipping...")
        pass


print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 0 of Set 1 | touros
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | pisco
# Processing Record 4 of Set 1 | witu
# Processing Record 5 of Set 1 | angul
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | macheng
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | bud
# Processing Record 10 of Set 1 | ahipara
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | christchurch
# Processing Record 13 of Set 1 | luanda
# Processing Record 14 of Set 1 | nanguneri
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | tyrma
# Processing Record 17 of Set 1 | bandarbeyla
# City not found. Skipping...
# Processing Record 18 of Set 1 | awbari
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | souillac
# Processing Record 22 of Set 1 | komsomolskiy
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | port hardy
# Processing Record 25 of Set 1 | cayenne
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | ambilobe
# Processing Record 29 of Set 1 | swift current
# Processing Record 30 of Set 1 | yerbogachen
# Processing Record 31 of Set 1 | kidal
# Processing Record 32 of Set 1 | baracoa
# Processing Record 33 of Set 1 | boshnyakovo
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | rundu
# Processing Record 37 of Set 1 | erenhot
# Processing Record 38 of Set 1 | bathsheba
# Processing Record 39 of Set 1 | lompoc
# Processing Record 40 of Set 1 | araouane
# Processing Record 41 of Set 1 | katsuura
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 27 of Set 4 | lircay
# Processing Record 28 of Set 4 | muros
# Processing Record 29 of Set 4 | mehamn
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | taltal
# City not found. Skipping...
# Processing Record 32 of Set 4 | pevek
# Processing Record 33 of Set 4 | tura
# Processing Record 34 of Set 4 | chimbote
# Processing Record 35 of Set 4 | okhotsk
# Processing Record 36 of Set 4 | coihaique
# Processing Record 37 of Set 4 | khatanga
# Processing Record 38 of Set 4 | deniliquin
# Processing Record 39 of Set 4 | matay
# Processing Record 40 of Set 4 | saldanha
# Processing Record 41 of Set 4 | butembo
# City not found. Skipping...
# Processing Record 42 of Set 4 | kenai
# Processing Record 43 of Set 4 | padang
# Processing Record 44 of Set 4 | portland
# Processing Record 45 of Set 4 | normandin
# Processing Record 46 of Set 4 | abu zabad
# City not found. Skipping...
# Processing Record 47 of Set 4 | longyearbyen
# City not found. Skipping...
# Processing Record 48 of Set 4 | warrensburg
# Processing Record 49 of Set 4 | geraldton
# Processing Record 0 of Set 5 | kapustin yar
# Processing Record 1 of Set 5 | krasnomayskiy
# Processing Record 2 of Set 5 | poya
# Processing Record 3 of Set 5 | kavieng
# Processing Record 4 of Set 5 | husavik
# Processing Record 5 of Set 5 | yanggu
# City not found. Skipping...
# Processing Record 6 of Set 5 | dalbandin
# Processing Record 7 of Set 5 | kurilsk
# Processing Record 8 of Set 5 | te anau
# Processing Record 9 of Set 5 | klaksvik
# Processing Record 10 of Set 5 | hamilton
# Processing Record 11 of Set 5 | myaundzha
# Processing Record 12 of Set 5 | chokurdakh
# Processing Record 13 of Set 5 | maniitsoq
# Processing Record 14 of Set 5 | mar del plata
# Processing Record 15 of Set 5 | oksfjord
# Processing Record 16 of Set 5 | nuuk
# Processing Record 17 of Set 5 | oussouye
# Processing Record 18 of Set 5 | ilulissat
# Processing Record 19 of Set 5 | gambo
# Processing Record 20 of Set 5 | college
# Processing Record 21 of Set 5 | verkhniy tagil
# Processing Record 22 of Set 5 | carsamba
# Processing Record 23 of Set 5 | malanje
# City not found. Skipping...
# Processing Record 24 of Set 5 | skeldon
# Processing Record 25 of Set 5 | pinega
# Processing Record 26 of Set 5 | dikson
# Processing Record 27 of Set 5 | port hedland
# Processing Record 28 of Set 5 | lodwar
# Processing Record 29 of Set 5 | brookhaven
# City not found. Skipping...
# Processing Record 30 of Set 5 | saskylakh
# Processing Record 31 of Set 5 | cabo san lucas
# Processing Record 32 of Set 5 | semnan
# Processing Record 33 of Set 5 | pecos
# Processing Record 34 of Set 5 | coquimbo
# Processing Record 35 of Set 5 | guhagar
# Processing Record 36 of Set 5 | sibu
# Processing Record 37 of Set 5 | turayf
# Processing Record 38 of Set 5 | chute-aux-outardes
# Processing Record 39 of Set 5 | vanimo
# Processing Record 40 of Set 5 | salina
# Processing Record 41 of Set 5 | bozeman
# Processing Record 42 of Set 5 | wismar
# Processing Record 43 of Set 5 | lujan
# Processing Record 44 of Set 5 | ransang
# City not found. Skipping...
# Processing Record 45 of Set 5 | kohila
# Processing Record 46 of Set 5 | walvis bay
# Processing Record 47 of Set 5 | portobelo
# Processing Record 48 of Set 5 | palasa
# City not found. Skipping...
# Processing Record 49 of Set 5 | hesperia
# Processing Record 0 of Set 6 | ketchikan
# Processing Record 1 of Set 6 | newport
# Processing Record 2 of Set 6 | brownwood
# Processing Record 3 of Set 6 | isangel
# Processing Record 4 of Set 6 | severodvinsk
# Processing Record 5 of Set 6 | broken hill
# Processing Record 6 of Set 6 | achacachi
# Processing Record 7 of Set 6 | alyangula
# Processing Record 8 of Set 6 | bengkulu
# Processing Record 9 of Set 6 | guamuchil
# Processing Record 10 of Set 6 | superior
# Processing Record 11 of Set 6 | hithadhoo
# Processing Record 12 of Set 6 | byron bay
# Processing Record 13 of Set 6 | amahai
# Processing Record 14 of Set 6 | boueni
# Processing Record 15 of Set 6 | vostok
# City not found. Skipping...
# Processing Record 16 of Set 6 | baruun-urt
# Processing Record 17 of Set 6 | mardin
# Processing Record 18 of Set 6 | tigil
# Processing Record 19 of Set 6 | pingshan
# Processing Record 20 of Set 6 | egvekinot
# Processing Record 21 of Set 6 | beloha
# Processing Record 22 of Set 6 | rio gallegos
# Processing Record 23 of Set 6 | havoysund
# Processing Record 24 of Set 6 | luoyang
# Processing Record 25 of Set 6 | veraval
# City not found. Skipping...
# Processing Record 26 of Set 6 | bismarck
# Processing Record 27 of Set 6 | iralaya
# Processing Record 28 of Set 6 | hakkari
# Processing Record 29 of Set 6 | kajaani
# Processing Record 30 of Set 6 | bubaque
# Processing Record 31 of Set 6 | broome
# Processing Record 32 of Set 6 | ust-maya
# Processing Record 33 of Set 6 | messina
# Processing Record 34 of Set 6 | dobele
# Processing Record 35 of Set 6 | naze
# City not found. Skipping...
# Processing Record 36 of Set 6 | pavlohrad
# Processing Record 37 of Set 6 | zolochiv
# Processing Record 38 of Set 6 | winona
# Processing Record 39 of Set 6 | san lorenzo
# Processing Record 40 of Set 6 | molina
# Processing Record 41 of Set 6 | mecca
# Processing Record 42 of Set 6 | micheweni
# Processing Record 43 of Set 6 | senneterre
# Processing Record 44 of Set 6 | portales
# Processing Record 45 of Set 6 | menongue
# Processing Record 46 of Set 6 | aljezur
# City not found. Skipping...
# Processing Record 47 of Set 6 | lockhart
# Processing Record 48 of Set 6 | tabou
# Processing Record 49 of Set 6 | arraial do cabo
# Processing Record 0 of Set 7 | jati
# Processing Record 1 of Set 7 | hasaki
# Processing Record 2 of Set 7 | santa rosa
# Processing Record 3 of Set 7 | bernardino de campos
# Processing Record 4 of Set 7 | xingcheng
# Processing Record 5 of Set 7 | brae
# Processing Record 6 of Set 7 | eydhafushi
# Processing Record 7 of Set 7 | gizo
# Processing Record 8 of Set 7 | progreso
# City not found. Skipping...
# Processing Record 9 of Set 7 | nikel
# Processing Record 10 of Set 7 | le port
# Processing Record 44 of Set 9 | kudahuvadhoo
# Processing Record 45 of Set 9 | yuanping
# Processing Record 46 of Set 9 | pacific grove
# Processing Record 47 of Set 9 | bloemfontein
# Processing Record 48 of Set 9 | krasnoarmeysk
# Processing Record 49 of Set 9 | santona
# Processing Record 0 of Set 10 | valerik
# Processing Record 1 of Set 10 | madera
# Processing Record 2 of Set 10 | hay river
# Processing Record 3 of Set 10 | zhanaozen
# Processing Record 4 of Set 10 | paracuru
# Processing Record 5 of Set 10 | umm lajj
# Processing Record 6 of Set 10 | qasigiannguit
# Processing Record 7 of Set 10 | elektrostal
# Processing Record 8 of Set 10 | bandar-e lengeh
# Processing Record 9 of Set 10 | kedrovka
# Processing Record 10 of Set 10 | santa maria
# Processing Record 11 of Set 10 | port hawkesbury
# Processing Record 12 of Set 10 | burnie
# Processing Record 13 of Set 10 | lagunas
# Processing Record 14 of Set 10 | mocuba
# Processing Record 15 of Set 10 | ust-nera
# Processing Record 16 of Set 10 | antofagasta
# Processing Record 17 of Set 10 | kathu
# Processing Record 18 of Set 10 | muravlenko
# Processing Record 19 of Set 10 | la rioja
# Processing Record 20 of Set 10 | tamiahua
# Processing Record 21 of Set 10 | kalakamati
# Processing Record 22 of Set 10 | muswellbrook
# City not found. Skipping...
# Processing Record 23 of Set 10 | nouadhibou
# Processing Record 24 of Set 10 | leninskoye
# Processing Record 25 of Set 10 | lahaina
# Processing Record 26 of Set 10 | isla mujeres
# Processing Record 27 of Set 10 | kavaratti
# Processing Record 28 of Set 10 | salalah
# Processing Record 29 of Set 10 | inegol
# Processing Record 30 of Set 10 | ostrovnoy
# Processing Record 31 of Set 10 | noshiro
# Processing Record 32 of Set 10 | suez
# Processing Record 33 of Set 10 | leningradskiy
# Processing Record 34 of Set 10 | corinto
# Processing Record 35 of Set 10 | la ronge
# Processing Record 36 of Set 10 | manicore
# Processing Record 37 of Set 10 | amazar
# Processing Record 38 of Set 10 | port-gentil
# Processing Record 39 of Set 10 | abdulino
# Processing Record 40 of Set 10 | pasighat
# Processing Record 41 of Set 10 | leh
# Processing Record 42 of Set 10 | bowen
# Processing Record 43 of Set 10 | maceio
# Processing Record 44 of Set 10 | srednekolymsk
# Processing Record 45 of Set 10 | lundazi
# City not found. Skipping...
# Processing Record 46 of Set 10 | bonthe
# City not found. Skipping...
# Processing Record 47 of Set 10 | port blair
# Processing Record 48 of Set 10 | znamenskoye
# Processing Record 49 of Set 10 | idenao
# Processing Record 0 of Set 11 | vrangel
# City not found. Skipping...
# Processing Record 1 of Set 11 | ajdabiya
# Processing Record 2 of Set 11 | troitskoye
# Processing Record 3 of Set 11 | yidu
# Processing Record 4 of Set 11 | nyurba
# Processing Record 5 of Set 11 | yambio
# Processing Record 6 of Set 11 | puerto ayacucho
# Processing Record 7 of Set 11 | kisangani
# Processing Record 8 of Set 11 | namatanai
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 11 | margate
# Processing Record 10 of Set 11 | hvide sande
# Processing Record 11 of Set 11 | cockburn town
# Processing Record 12 of Set 11 | kinango
# Processing Record 13 of Set 11 | mayor pablo lagerenza
# Processing Record 14 of Set 11 | edson
# Processing Record 15 of Set 11 | tommot
# Processing Record 16 of Set 11 | parrita
# Processing Record 17 of Set 11 | manokwari
# Processing Record 18 of Set 11 | wetter
# Processing Record 19 of Set 11 | virginia beach
# Processing Record 20 of Set 11 | bam
# Processing Record 21 of Set 11 | mirnyy
# Processing Record 22 of Set 11 | lumeje
# Processing Record 23 of Set 11 | kununurra
# Processing Record 24 of Set 11 | springfield
# Processing Record 25 of Set 11 | palestina
# Processing Record 26 of Set 11 | thai binh
# Processing Record 27 of Set 11 | trat
# Processing Record 28 of Set 11 | bryukhovetskaya
# Processing Record 29 of Set 11 | sao filipe
# Processing Record 30 of Set 11 | reichenau
# Processing Record 31 of Set 11 | belmonte
# Processing Record 32 of Set 11 | san isidro
# Processing Record 33 of Set 11 | manica
# Processing Record 34 of Set 11 | soe
# Processing Record 35 of Set 11 | ylivieska
# Processing Record 36 of Set 11 | skegness
# Processing Record 37 of Set 11 | horodnytsya
# Processing Record 38 of Set 11 | lavrentiya
# Processing Record 39 of Set 11 | labuhan
# Processing Record 40 of Set 11 | portel
# Processing Record 41 of Set 11 | ken caryl
# Processing Record 42 of Set 11 | luohe
# Processing Record 43 of Set 11 | port lincoln
# Processing Record 44 of Set 11 | aklavik
# City not found. Skipping...
# Processing Record 45 of Set 11 | sosnovo-ozerskoye
# Processing Record 46 of Set 11 | pangnirtung
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
#Exporting the city data into a .csv and Displaying the DataFrame.


weather_data = pd.DataFrame({"City":City,"Cloudiness":Cloudiness,"Country":Country,"Date":Date,
                             "Humidity":Humidity,"Latitude":Lat,"Longitude":Lng,"Max Temperature":Max_temp,"Wind Speed":Wind_Speed})

weather_data.to_csv("output_data_file", index=False, header=True)

weather_data
# Out:
#                   City  Cloudiness Country        Date  Humidity  Latitude  \
# 0               Touros          40      BR  1583947840        62     -5.20
# 1               Albany          90      US  1583947707        36     42.60
# 2           Butaritari         100      KI  1583947843        77      3.07
# 3                Pisco           0      PE  1583947792        30    -13.70
# 4                 Witu         100      KE  1583947845        79     -2.39
# ..                 ...         ...     ...         ...       ...       ...
# 542              Luohe          80      CN  1583948496        67     33.57
# 543       Port Lincoln          98      AU  1583948305        38    -34.73
# 544            Aklavik          75      CA  1583948499        75     68.22
# 545  Sosnovo-Ozerskoye           0      RU  1583948501        88     52.52
# 546        Pangnirtung           5      CA  1583948502        68     66.15
#
#      Longitude  Max Temperature  Wind Speed
# 0       -35.46            87.80       11.41
# 1       -73.97            45.00        5.82
# 2       172.79            83.23       17.36
# 3       -76.22            79.00       11.41
# 4        40.44            82.20       13.47
# ..         ...              ...         ...
# 542     114.04            50.59        7.52
# 543     135.87            76.80        8.99
# 544    -135.01           -16.60        2.24
# 545     111.54            -4.74        8.19
# 546     -65.71           -16.60        2.24
#
# [547 rows x 9 columns]

# %% [markdown]
# # Scatter Plots

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
#Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#Save the plotted figures as .pngs.

#Latitude vs. Temperature Plot

x_axis = weather_data["Latitude"]
y_axis = weather_data["Max Temperature"]
timestamp = weather_data["Date"][1]
Date = time.strftime("%D", time.localtime(int(timestamp)))
plt.xlim((weather_data["Latitude"]).min()-10,(weather_data["Latitude"]).max()+10)
plt.grid()
plt.title(f"City Latitude vs Maximum Temperature ({Date})")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (F)")
plt.scatter(x_axis,y_axis, marker="o", facecolors="green", edgecolors="black", alpha=0.75)
plt.savefig("Images/Temp_max.png")

# %% [markdown]
# The above code is plotting the maximum temperature vs latitude. The above plot indicates that as the latitude increases above zero the temperature seems to be decreasing, also as the latitude decreases below zero the temperature starts decreasing. Hence some of the highest maximum teperatures are between -20 and 20 degree latitude which is around the Equator.

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
#Latitude vs. Humidity Plot

x_axis = weather_data["Latitude"]
y_axis = weather_data["Humidity"]
plt.grid()
plt.title(f"City Latitude vs Humidity ({Date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.scatter(x_axis,y_axis, marker="o", facecolors="red", edgecolors="black", alpha=0.75)
plt.savefig("Images/Humidity.png")

# %% [markdown]
# The above code is plotting a relationship between Latitude vs. Humidity. As we can see from the plot most of the cities seem to have high humdity between 60% and 90%. There are however a handfull of cities which have humidity level below 20%.

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
#Latitude vs. Cloudiness Plot

x_axis = weather_data["Latitude"]
y_axis = weather_data["Cloudiness"]
plt.grid()
plt.title(f"City Latitude vs Cloudiness ({Date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.scatter(x_axis,y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75)
plt.savefig("Images/Cloudiness.png")

# %% [markdown]
# The above code is plotting the relationship between Latitude vs. Cloudiness. The cloudiness seems to vary from one city to another as we can see from the plot. There are certain cities which are 100% cloudy to some that have 0% cloudy. It also certainly depends on the time of the day that we are running this code as the latitudes plotted belong to cities spread across the world.

# %% [markdown]
# # Latitude vs Wind Speed plot

# %%
#Latitude vs. Wind Speed Plot

x_axis = weather_data["Latitude"]
y_axis = weather_data["Wind Speed"]
plt.grid()
plt.title(f"City Latitude vs Wind Speed ({Date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.scatter(x_axis,y_axis, marker="o", facecolors="yellow", edgecolors="black",alpha=0.75)
plt.savefig("Images/Wind_Speed.png")

# %% [markdown]
# The above code plots the relationship between Latitude vs. Wind Speed. As we can see most of the cities seem to have a very low windspeed between 0 to 10 mph. However there are few cities at around the 60 and 80 degree latitude that show a slight increase in windspeed.

# %%
# Creating a function to plot Linear Regression

def linear_regression(x_values,y_values,color):
    (slope,intercept,rvalue,pvalue,stderr) = linregress(x_values,y_values)
    print(f"The r-squared is: {rvalue}")
    regress_value = x_values*slope + intercept
    plt.scatter(x_values,y_values, marker="o", facecolors=color, edgecolors="black",alpha=0.75)
    plt.plot(x_values,regress_value,"r-")
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.annotate(line_eq,(x_values.max()-50,y_values.min()),fontsize=15,color='red')

# %%
# Creating Northern and Southern Hemisphere DataFrames    

#Northern Hemishere DataFrame
Data_north = weather_data.loc[weather_data["Latitude"]>=0,:]

#Southern Hemishere DataFrame
Data_south = weather_data.loc[weather_data["Latitude"]<0,:]

# %% [markdown]
# # Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression

plt.title(f"Northern Hemisphere - Max Temp (F) vs. Latitude Linear Regression ({Date})")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (F)")
linear_regression(Data_north["Latitude"],Data_north["Max Temperature"],"green")
plt.savefig("Images/Temp_North.png")
# Out:
# The r-squared is: -0.8588130215247977

# %% [markdown]
# # Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression

plt.title(f"Southern Hemisphere - Max Temp (F) vs. Latitude Linear Regression ({Date})")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (F)")
linear_regression(Data_south["Latitude"],Data_south["Max Temperature"],"green")
plt.savefig("Images/Temp_South.png")
# Out:
# The r-squared is: 0.5425461710608359

# %% [markdown]
# The above 2 plots show the relationship between the Max Temp vs. Latitude as seen on the Northern and Southern hemishpere.
# Temperature seems to gradually decrease as we move away from the equator towards the North which is indicated by the Northern hemishere plot.
# Similarly, temperature seems to steadily decrese as we move more towards the south from the Equator as shown in the Southern hemishere plot.
# Consequently we can conclude that the highest tempeatures on earth are around the Equator.

# %% [markdown]
# # Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

plt.title(f"Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression ({Date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
linear_regression(Data_north["Latitude"],Data_north["Humidity"],"red")
plt.savefig("Images/Humidity_North.png")
# Out:
# The r-squared is: 0.41143773761568286

# %% [markdown]
# # Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

plt.title(f"Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression ({Date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
linear_regression(Data_south["Latitude"],Data_south["Humidity"],"red")
plt.savefig("Images/Humidity_South.png")
# Out:
# The r-squared is: 0.07285556147727154

# %% [markdown]
# The above plots show the Humidity (%) vs. Latitude Linear Regression in the Nothern and Southern hemisphere.
# There seems to be slightly positive corelation between the humidity and latitude in the Northern hemisphere athough it is very low as the r squared value is not close to 1.
# In the Southern hemishpere there is not much relationship that could be establishes as the r squared value is very low and hence this subset might not be ideal to draw any conclusions.

# %% [markdown]
# # Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

plt.title(f"Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression ({Date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
linear_regression(Data_north["Latitude"],Data_north["Cloudiness"],"blue")
plt.savefig("Images/Cloudiness_North.png")
# Out:
# The r-squared is: 0.1402635638883881

# %% [markdown]
# # Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression ({Date})")
linear_regression(Data_south["Latitude"],Data_south["Cloudiness"],"blue")
plt.savefig("Images/Cloudiness_South.png")
# Out:
# The r-squared is: 0.2178046907571641

# %% [markdown]
# The 2 above plots show the relationship between Cloudiness (%) vs. Latitude Linear Regression in the Northen and Southern hemisphere respectively.
# In both the Northern and Southern hemisphere the linear regression seems to model a weak fit as there seems to be very weak corelation between the two factors. The r squared values are extemely low for both the hemispheres.

# %% [markdown]
# # Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression ({Date})")
linear_regression(Data_north["Latitude"],Data_north["Wind Speed"],"Yellow")
plt.savefig("Images/Windspeed_North.png")
# Out:
# The r-squared is: 0.13952993287623133

# %% [markdown]
# # Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression ({Date})")
linear_regression(Data_south["Latitude"],Data_south["Wind Speed"],"Yellow")
plt.savefig("Images/Windspeed_South.png")
# Out:
# The r-squared is: -0.13010776838399124

# %% [markdown]
# The 2 plots show the relationshop between Wind Speed (mph) vs. Latitude Linear Regression for the Northern and Southern Hemisphere
# Once again there is not much realtionship or conclusion that we can draw from the linear regression. There seems to be not much realtionship between the 2 factors as the rsquare values are also pretty low.
